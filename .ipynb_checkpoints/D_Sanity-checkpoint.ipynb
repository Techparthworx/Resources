# %%
# make sure you press shift enter in order to load modules

import pandas as pd
import os

# %% [markdown]
# Loading Data

# %%
data_path = os.path.join(os.getcwd(), "data_dir","fishing_data_na.csv")
data_df = pd.read_csv(data_path)

# %% [markdown]
# Sanity Check

# %%
data_df.head(4)
# Out:
#    day_count day_of_week  num_big_fish  num_small_fish river_type
# 0          1      Monday           4.0             7.0      North
# 1          2     Tuesday           3.0            10.0      North
# 2          3   Wednesday           9.0            16.0      North
# 3          4    Thursday           6.0            15.0      North

# %%
data_df.tail(4)
# Out:
#     day_count day_of_week  num_big_fish  num_small_fish river_type
# 56         57      Monday           8.0             NaN      North
# 57         58     Tuesday           3.0             NaN      North
# 58         59   Wednesday           8.0            13.0      North
# 59         60    Thursday           5.0            20.0        NaN

# %%
 data_df.iloc[5:8]  #see random rows
# Out:
#    day_count day_of_week  num_big_fish  num_small_fish river_type
# 5          6    Saturday           NaN             3.0      South
# 6          7      Sunday           6.0             3.0      South
# 7          8      Monday           3.0            11.0      North

# %%
data_df.shape  #shape of the data *number of rows and columns
# Out:
# (60, 5)

# %%
list(data_df)  # df means data frame, columns in a list
# Out:
# ['day_count', 'day_of_week', 'num_big_fish', 'num_small_fish', 'river_type']

# %%
data_df.columns  #Column index similar to above
# Out:
# Index(['day_count', 'day_of_week', 'num_big_fish', 'num_small_fish',
#        'river_type'],
#       dtype='object')

# %%
data_df.index  #data index starting from and ending
# Out:
# RangeIndex(start=0, stop=60, step=1)

# %%
data_df.dtypes  # data types
# Out:
# day_count           int64
# day_of_week        object
# num_big_fish      float64
# num_small_fish    float64
# river_type         object
# dtype: object

# %% [markdown]
# Missing Value Check

# %%
data_df.isna()  #mising data
# Out:
#     day_count  day_of_week  num_big_fish  num_small_fish  river_type
# 0       False        False         False           False       False
# 1       False        False         False           False       False
# 2       False        False         False           False       False
# 3       False        False         False           False       False
# 4       False        False         False           False       False
# 5       False        False          True           False       False
# 6       False        False         False           False       False
# 7       False        False         False           False       False
# 8       False        False         False           False       False
# 9       False        False         False           False       False
# 10      False        False         False            True       False
# 11      False        False         False           False        True
# 12      False        False         False            True       False
# ...

# %%
data_df.isna().sum()  #wittering down column wise missing values.
# Out:
# day_count         0
# day_of_week       0
# num_big_fish      5
# num_small_fish    5
# river_type        3
# dtype: int64

# %%
data_df.isna().sum(axis=0) #column wise going right------->
# Out:
# day_count         0
# day_of_week       0
# num_big_fish      5
# num_small_fish    5
# river_type        3
# dtype: int64

# %%
data_df.isna().sum(axis=1) #row wise going down/

# %%
data_df.isna().mean() # missing values
# Out:
# day_count         0.000000
# day_of_week       0.000000
# num_big_fish      0.083333
# num_small_fish    0.083333
# river_type        0.050000
# dtype: float64

# %%
data_df.isna().sum().sort_values(ascending=False)
# Out:
# num_big_fish      5
# num_small_fish    5
# river_type        3
# day_count         0
# day_of_week       0
# dtype: int64

# %%
data_df.isna().mean().sort_values(ascending=False) *100 #percentage of mising values in a  column
# Out:
# num_big_fish      8.333333
# num_small_fish    8.333333
# river_type        5.000000
# day_count         0.000000
# day_of_week       0.000000
# dtype: float64

# %%
data_df  #looking at all the data at a glance. Eyeballing
# Out:
#     day_count day_of_week  num_big_fish  num_small_fish river_type
# 0           1      Monday           4.0             7.0      North
# 1           2     Tuesday           3.0            10.0      North
# 2           3   Wednesday           9.0            16.0      North
# 3           4    Thursday           6.0            15.0      North
# 4           5      Friday           4.0            22.0      North
# 5           6    Saturday           NaN             3.0      South
# 6           7      Sunday           6.0             3.0      South
# 7           8      Monday           3.0            11.0      North
# 8           9     Tuesday           6.0            16.0      North
# 9          10   Wednesday           6.0             8.0      North
# 10         11    Thursday           4.0             NaN      North
# 11         12      Friday           6.0            17.0        NaN
# 12         13    Saturday          13.0             NaN      South
# ...
